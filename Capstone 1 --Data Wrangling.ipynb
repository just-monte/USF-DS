# %% [markdown]
# Imports

# %%
# Imports 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
# Loading datasets 

#dataset #1 - Gradute/Drop-out Rates
grad_rates = pd.read_csv('GraduateRate.csv')

#dataset #2 - Global Education Stats 
ed_stats = pd.read_csv('EdStatsData.csv')

# %% [markdown]
# Cleaning & Sorting Datasets

# %%
#Part 2a: Dataset #1 - Predict Student Drop-out & Succes 
grad_rates.head()
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                17                  5     171
# 1               1                15                  1    9254
# 2               1                 1                  5    9070
# 3               1                17                  2    9773
# 4               2                39                  1    8014
#
#    Daytime/evening attendance\t  Previous qualification  \
# 0                             1                       1
# 1                             1                       1
# 2                             1                       1
# 3                             1                       1
# 4                             0                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  \
# 0                           122.0            1                      19
# 1                           160.0            1                       1
# ...

# %%
grad_rates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 37 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Marital status                                  4424 non-null   int64
#  1   Application mode                                4424 non-null   int64
#  2   Application order                               4424 non-null   int64
#  3   Course                                          4424 non-null   int64
#  4   Daytime/evening attendance	                     4424 non-null   int64
#  5   Previous qualification                          4424 non-null   int64
#  6   Previous qualification (grade)                  4424 non-null   float64
#  7   Nacionality                                     4424 non-null   int64
#  8   Mother's qualification                          4424 non-null   int64
# ...

# %%
# Count of Nacionatilites 
# 1- Portuguese; 2 - German; 6 - Spanish; 11 - Italian; 13 - Dutch; 14 - English; 17 - Lithuanian; 21 - Angolan; 22 - Cape Verdean; 24 - Guinean; 25 - Mozambican; 26 - Santomean; 32 - Turkish; 41 - Brazilian; 62 - Romanian; 100 - Moldova (Republic of); 101 - Mexican; 103 - Ukrainian; 105 - Russian; 108 - Cuban; 109 - Colombian
grad_rates['Nacionality'].value_counts()
# Out:
# 1      4314
# 41       38
# 26       14
# 22       13
# 6        13
# 24        5
# 100       3
# 11        3
# 103       3
# 21        2
# 101       2
# 62        2
# 25        2
# 2         2
# 105       2
# 32        1
# 13        1
# 109       1
# 108       1
# 14        1
# 17        1
# Name: Nacionality, dtype: int64

# %%
grad_rates['Curricular units 1st sem (without evaluations)'].value_counts()
# Out:
# 0     4130
# 1      153
# 2       79
# 3       23
# 4       15
# 6        6
# 7        6
# 5        5
# 8        4
# 12       2
# 10       1
# Name: Curricular units 1st sem (without evaluations), dtype: int64

# %%
grad_rates['Curricular units 1st sem (evaluations)'].value_counts()
# Out:
# 8     791
# 7     703
# 6     598
# 9     402
# 0     349
# 10    340
# 11    239
# 12    223
# 5     220
# 13    140
# 14    105
# 15     70
# 16     47
# 17     33
# 18     30
# 19     23
# 4      19
# 21     17
# 20     12
# 22     10
# 23      9
# 2       8
# 3       6
# 24      6
# 1       6
# 26      4
# 25      3
# 27      2
# 29      2
# 45      2
# 32      1
# 36      1
# 31      1
# 28      1
# 33      1
# Name: Curricular units 1st sem (evaluations), dtype: int64

# %%
grad_rates['Curricular units 2nd sem (without evaluations)'].value_counts()
# Out:
# 0     4142
# 1      140
# 2       48
# 3       35
# 4       21
# 5       17
# 6        8
# 8        6
# 7        5
# 12       2
# Name: Curricular units 2nd sem (without evaluations), dtype: int64

# %%
grad_rates['Curricular units 2nd sem (evaluations)'].value_counts()
# Out:
# 8     792
# 6     614
# 7     563
# 9     456
# 0     401
# 10    355
# 5     288
# 11    255
# 12    226
# 13    126
# 14     98
# 15     73
# 16     49
# 17     25
# 18     22
# 19     19
# 4      10
# 21     10
# 22     10
# 20      8
# 2       4
# 23      4
# 26      3
# 24      3
# 1       3
# 3       2
# 27      2
# 28      1
# 25      1
# 33      1
# Name: Curricular units 2nd sem (evaluations), dtype: int64

# %%
# removing evaluations & without evalution columns 
del grad_rates['Curricular units 2nd sem (without evaluations)']
del grad_rates['Curricular units 2nd sem (evaluations)']
del grad_rates['Curricular units 1st sem (without evaluations)']
del grad_rates['Curricular units 1st sem (evaluations)']

# %%
grad_rates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 33 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Marital status                       4424 non-null   int64
#  1   Application mode                     4424 non-null   int64
#  2   Application order                    4424 non-null   int64
#  3   Course                               4424 non-null   int64
#  4   Daytime/evening attendance	          4424 non-null   int64
#  5   Previous qualification               4424 non-null   int64
#  6   Previous qualification (grade)       4424 non-null   float64
#  7   Nacionality                          4424 non-null   int64
#  8   Mother's qualification               4424 non-null   int64
#  9   Father's qualification               4424 non-null   int64
#  10  Mother's occupation                  4424 non-null   int64
# ...

# %%
#Part 2b: Dataset #2: ed stats

# %%
ed_stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 886930 entries, 0 to 886929
# Data columns (total 49 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Country Name    886930 non-null  object
#  1   Country Code    886930 non-null  object
#  2   Indicator Name  886930 non-null  object
#  3   Indicator Code  886930 non-null  object
#  4   1970            72288 non-null   float64
#  5   1971            35537 non-null   float64
#  6   1972            35619 non-null   float64
#  7   1973            35545 non-null   float64
#  8   1974            35730 non-null   float64
#  9   1975            87306 non-null   float64
#  10  1976            37483 non-null   float64
#  11  1977            37574 non-null   float64
#  12  1978            37576 non-null   float64
#  13  1979            36809 non-null   float64
#  14  1980            89122 non-null   float64
#  15  1981            38777 non-null   float64
# ...

# %%
educ_stats = ed_stats[['Country Name', 'Country Code', 'Indicator Name', '2014']].copy()
print(educ_stats.head())
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
#
#                                       Indicator Name       2014
# 0  Adjusted net enrolment rate, lower secondary, ...        NaN
# 1  Adjusted net enrolment rate, lower secondary, ...        NaN
# 2  Adjusted net enrolment rate, lower secondary, ...        NaN
# 3  Adjusted net enrolment rate, lower secondary, ...        NaN
# 4  Adjusted net enrolment rate, primary, both sex...  85.320152

# %%
educ_stats = educ_stats.dropna(axis='rows')
educ_stats
# Out:
#        Country Name Country Code  \
# 4        Arab World          ARB
# 5        Arab World          ARB
# 6        Arab World          ARB
# 7        Arab World          ARB
# 12       Arab World          ARB
# ...             ...          ...
# 886925     Zimbabwe          ZWE
# 886926     Zimbabwe          ZWE
# 886927     Zimbabwe          ZWE
# 886928     Zimbabwe          ZWE
# 886929     Zimbabwe          ZWE
#
#                                            Indicator Name           2014
# 4       Adjusted net enrolment rate, primary, both sex...      85.320152
# 5        Adjusted net enrolment rate, primary, female (%)      83.820831
# 6       Adjusted net enrolment rate, primary, gender p...       0.966200
# 7          Adjusted net enrolment rate, primary, male (%)      86.753387
# 12      Adjusted net intake rate to Grade 1 of primary...      76.620567
# ...                                                   ...            ...
# ...

# %%
# 1st factor of interest: Adjusted net enrolment rate, lower secondary, both sexes (%)

# %%
adj_enroll = educ_stats.loc[educ_stats['Indicator Name'] == 'Adjusted net enrolment rate, lower secondary, both sexes (%)']

# %%
# Spain enroll rate lower secondary 
adj_enroll.loc[adj_enroll['Country Name'].str.contains("Spain", case=False)]
# Out:
#        Country Name Country Code  \
# 743995        Spain          ESP
#
#                                            Indicator Name       2014
# 743995  Adjusted net enrolment rate, lower secondary, ...  94.076622

# %%
# Portugal enroll rate 
adj_enroll.loc[adj_enroll['Country Name'].str.contains("Portugal", case=False)]
# Out:
#        Country Name Country Code  \
# 663365     Portugal          PRT
#
#                                            Indicator Name       2014
# 663365  Adjusted net enrolment rate, lower secondary, ...  85.185539

# %%
# Germany enroll rate 
adj_enroll.loc[adj_enroll['Country Name'].str.contains("Germany", case=False)]
# Out:
# Empty DataFrame
# Columns: [Country Name, Country Code, Indicator Name, 2014]
# Index: []

# %%
# Italy enroll rate 
adj_enroll.loc[adj_enroll['Country Name'].str.contains("Italy", case=False)]
# Out:
# Empty DataFrame
# Columns: [Country Name, Country Code, Indicator Name, 2014]
# Index: []

# %%
# Netherlands enroll rate 
adj_enroll.loc[adj_enroll['Country Name'].str.contains("Netherlands", case=False)]
# Out:
# Empty DataFrame
# Columns: [Country Name, Country Code, Indicator Name, 2014]
# Index: []

# %%
#Lithuania enroll rate 
adj_enroll.loc[adj_enroll['Country Name'].str.contains("Lithuania", case=False)]
# Out:
#        Country Name Country Code  \
# 509435    Lithuania          LTU
#
#                                            Indicator Name       2014
# 509435  Adjusted net enrolment rate, lower secondary, ...  99.405693

# %%
#UK enroll rate 
adj_enroll.loc[adj_enroll['Country Name'].str.contains("United Kingdom", case=False)]
# Out:
#           Country Name Country Code  \
# 842950  United Kingdom          GBR
#
#                                            Indicator Name       2014
# 842950  Adjusted net enrolment rate, lower secondary, ...  96.082527

# %%
# Anogola enroll rate 
adj_enroll.loc[adj_enroll['Country Name'].str.contains("Anogola", case=False)]
# Out:
# Empty DataFrame
# Columns: [Country Name, Country Code, Indicator Name, 2014]
# Index: []

# %%
# Cabo verde enroll rate 
adj_enroll.loc[adj_enroll['Country Name'].str.contains("Cabo Verde", case=False)]
# Out:
#        Country Name Country Code  \
# 208905   Cabo Verde          CPV
#
#                                            Indicator Name       2014
# 208905  Adjusted net enrolment rate, lower secondary, ...  68.356537

# %%
# Guinea enroll rate 
adj_enroll.loc[adj_enroll['Country Name'].str.contains("Guinea", case=False)]
# Out:
#        Country Name Country Code  \
# 384825       Guinea          GIN
#
#                                            Indicator Name       2014
# 384825  Adjusted net enrolment rate, lower secondary, ...  32.690689

# %%
#Mozambique enroll rate 
adj_enroll.loc[adj_enroll['Country Name'].str.contains("Mozambique", case=False)]
# Out:
#        Country Name Country Code  \
# 582735   Mozambique          MOZ
#
#                                            Indicator Name       2014
# 582735  Adjusted net enrolment rate, lower secondary, ...  16.120781

# %%
# Sao Tome and Principe enroll rate 
adj_enroll.loc[adj_enroll['Country Name'].str.contains("Sao Tome", case=False)]
# Out:
# Empty DataFrame
# Columns: [Country Name, Country Code, Indicator Name, 2014]
# Index: []

# %%
#Turkey enroll rate 
adj_enroll.loc[adj_enroll['Country Name'].str.contains("Turkey", case=False)]
# Out:
# Empty DataFrame
# Columns: [Country Name, Country Code, Indicator Name, 2014]
# Index: []

# %%
# Brazil enroll rate 
adj_enroll.loc[adj_enroll['Country Name'].str.contains("Brazil", case=False)]
# Out:
# Empty DataFrame
# Columns: [Country Name, Country Code, Indicator Name, 2014]
# Index: []

# %%
# Romania enroll rate 
adj_enroll.loc[adj_enroll['Country Name'].str.contains("Romania", case=False)]
# Out:
#        Country Name Country Code  \
# 674360      Romania          ROU
#
#                                            Indicator Name       2014
# 674360  Adjusted net enrolment rate, lower secondary, ...  89.185013

# %%
# Moldova enroll rate 
adj_enroll.loc[adj_enroll['Country Name'].str.contains("Moldova", case=False)]
# Out:
#        Country Name Country Code  \
# 564410      Moldova          MDA
#
#                                            Indicator Name      2014
# 564410  Adjusted net enrolment rate, lower secondary, ...  84.32338

# %%
# Mexico enroll rate 
adj_enroll.loc[adj_enroll['Country Name'].str.contains("Mexico", case=False)]
# Out:
# Empty DataFrame
# Columns: [Country Name, Country Code, Indicator Name, 2014]
# Index: []

# %%
# Ukraine enroll rate 
adj_enroll.loc[adj_enroll['Country Name'].str.contains("Ukraine", case=False)]
# Out:
#        Country Name Country Code  \
# 835620      Ukraine          UKR
#
#                                            Indicator Name       2014
# 835620  Adjusted net enrolment rate, lower secondary, ...  93.078461

# %%
# Cuba enroll rate 
adj_enroll.loc[adj_enroll['Country Name'].str.contains("Cuba", case=False)]
# Out:
# Empty DataFrame
# Columns: [Country Name, Country Code, Indicator Name, 2014]
# Index: []

# %%
# Russia enroll rate 
adj_enroll.loc[adj_enroll['Country Name'].str.contains("Russia", case=False)]
# Out:
# Empty DataFrame
# Columns: [Country Name, Country Code, Indicator Name, 2014]
# Index: []

# %%
# Colombia enroll rate 
adj_enroll.loc[adj_enroll['Country Name'].str.contains("Colombia", case=False)]
# Out:
#        Country Name Country Code  \
# 245555     Colombia          COL
#
#                                            Indicator Name       2014
# 245555  Adjusted net enrolment rate, lower secondary, ...  78.926567

# %%
# Dataframe of adj secondary enrollement 
secondary_enrollment = adj_enroll.loc[[743995,663365,842950,509435,208905,384825,582735,674360,564410,245555,835620]]
secondary_enrollment = pd.DataFrame(secondary_enrollment) 
secondary_enrollment
# Out:
#           Country Name Country Code  \
# 743995           Spain          ESP
# 663365        Portugal          PRT
# 842950  United Kingdom          GBR
# 509435       Lithuania          LTU
# 208905      Cabo Verde          CPV
# 384825          Guinea          GIN
# 582735      Mozambique          MOZ
# 674360         Romania          ROU
# 564410         Moldova          MDA
# 245555        Colombia          COL
# 835620         Ukraine          UKR
#
#                                            Indicator Name       2014
# 743995  Adjusted net enrolment rate, lower secondary, ...  94.076622
# 663365  Adjusted net enrolment rate, lower secondary, ...  85.185539
# 842950  Adjusted net enrolment rate, lower secondary, ...  96.082527
# 509435  Adjusted net enrolment rate, lower secondary, ...  99.405693
# 208905  Adjusted net enrolment rate, lower secondary, ...  68.356537
# 384825  Adjusted net enrolment rate, lower secondary, ...  32.690689
# ...

# %%
# 2nd factor of interest: Enrollment of tertiary education (all programs)

# %%
ter_educ = educ_stats.loc[educ_stats['Indicator Name'] == 'Enrolment in tertiary education, all programmes, both sexes (number)']

# %%
# Spain ter educ enrollment 
ter_educ.loc[ter_educ['Country Name'].str.contains("Spain", case=False)]
# Out:
#        Country Name Country Code  \
# 745199        Spain          ESP
#
#                                            Indicator Name       2014
# 745199  Enrolment in tertiary education, all programme...  1982162.0

# %%
# Portugal ter educ enrollment 
ter_educ.loc[ter_educ['Country Name'].str.contains("Portugal", case=False)]
# Out:
#        Country Name Country Code  \
# 664569     Portugal          PRT
#
#                                            Indicator Name      2014
# 664569  Enrolment in tertiary education, all programme...  362200.0

# %%
# Germany ter educ enrollment 
ter_educ.loc[ter_educ['Country Name'].str.contains("Germany", case=False)]
# Out:
#        Country Name Country Code  \
# 356709      Germany          DEU
#
#                                            Indicator Name       2014
# 356709  Enrolment in tertiary education, all programme...  2912203.5

# %%
#Italy 
ter_educ.loc[ter_educ['Country Name'].str.contains("Italy", case=False)]
# Out:
#        Country Name Country Code  \
# 441004        Italy          ITA
#
#                                            Indicator Name       2014
# 441004  Enrolment in tertiary education, all programme...  1854360.0

# %%
#Netherlands 
ter_educ.loc[ter_educ['Country Name'].str.contains("Netherlands", case=False)]
# Out:
# Empty DataFrame
# Columns: [Country Name, Country Code, Indicator Name, 2014]
# Index: []

# %%
# Lithuania 
ter_educ.loc[ter_educ['Country Name'].str.contains("Lithuania", case=False)]
# Out:
#        Country Name Country Code  \
# 510639    Lithuania          LTU
#
#                                            Indicator Name      2014
# 510639  Enrolment in tertiary education, all programme...  148389.0

# %%
# UK 
ter_educ.loc[ter_educ['Country Name'].str.contains("United Kingdom", case=False)]
# Out:
#           Country Name Country Code  \
# 844154  United Kingdom          GBR
#
#                                            Indicator Name        2014
# 844154  Enrolment in tertiary education, all programme...  2352932.75

# %%
# Anogola 
ter_educ.loc[ter_educ['Country Name'].str.contains("Anogola", case=False)]
# Out:
# Empty DataFrame
# Columns: [Country Name, Country Code, Indicator Name, 2014]
# Index: []

# %%
#Cabo Verde 
ter_educ.loc[ter_educ['Country Name'].str.contains("Cabo Verde", case=False)]
# Out:
#        Country Name Country Code  \
# 210109   Cabo Verde          CPV
#
#                                            Indicator Name     2014
# 210109  Enrolment in tertiary education, all programme...  13397.0

# %%
# Guinea 
ter_educ.loc[ter_educ['Country Name'].str.contains("Guinea", case=False)]
# Out:
#        Country Name Country Code  \
# 386029       Guinea          GIN
#
#                                            Indicator Name      2014
# 386029  Enrolment in tertiary education, all programme...  117943.0

# %%
# Mozambique
ter_educ.loc[ter_educ['Country Name'].str.contains("Mozambique", case=False)]
# Out:
#        Country Name Country Code  \
# 583939   Mozambique          MOZ
#
#                                            Indicator Name      2014
# 583939  Enrolment in tertiary education, all programme...  157431.0

# %%
# Sao Tome and Principe
ter_educ.loc[ter_educ['Country Name'].str.contains("Sao Tome and Principe", case=False)]
# Out:
#                  Country Name Country Code  \
# 693889  Sao Tome and Principe          STP
#
#                                            Indicator Name    2014
# 693889  Enrolment in tertiary education, all programme...  1680.0

# %%
# Turkey 
ter_educ.loc[ter_educ['Country Name'].str.contains("Turkey", case=False)]
# Out:
#        Country Name Country Code  \
# 818499       Turkey          TUR
#
#                                            Indicator Name       2014
# 818499  Enrolment in tertiary education, all programme...  5472521.0

# %%
# Brazil 
ter_educ.loc[ter_educ['Country Name'].str.contains("Brazil", case=False)]
# Out:
#        Country Name Country Code  \
# 188119       Brazil          BRA
#
#                                            Indicator Name       2014
# 188119  Enrolment in tertiary education, all programme...  8072146.0

# %%
# Romania 
ter_educ.loc[ter_educ['Country Name'].str.contains("Romania", case=False)]
# Out:
#        Country Name Country Code  \
# 675564      Romania          ROU
#
#                                            Indicator Name      2014
# 675564  Enrolment in tertiary education, all programme...  578706.0

# %%
# Moldova
ter_educ.loc[ter_educ['Country Name'].str.contains("Moldova", case=False)]
# Out:
#        Country Name Country Code  \
# 565614      Moldova          MDA
#
#                                            Indicator Name      2014
# 565614  Enrolment in tertiary education, all programme...  116325.0

# %%
# Mexico 
ter_educ.loc[ter_educ['Country Name'].str.contains("Mexico", case=False)]
# Out:
#        Country Name Country Code  \
# 558284       Mexico          MEX
#
#                                            Indicator Name       2014
# 558284  Enrolment in tertiary education, all programme...  3419391.0

# %%
#Ukraine 
ter_educ.loc[ter_educ['Country Name'].str.contains("Ukraine", case=False)]
# Out:
#        Country Name Country Code  \
# 836824      Ukraine          UKR
#
#                                            Indicator Name       2014
# 836824  Enrolment in tertiary education, all programme...  2146028.0

# %%
#Cuba
ter_educ.loc[ter_educ['Country Name'].str.contains("Cuba", case=False)]
# Out:
#        Country Name Country Code  \
# 272414         Cuba          CUB
#
#                                            Indicator Name      2014
# 272414  Enrolment in tertiary education, all programme...  301773.0

# %%
#Russia 
ter_educ.loc[ter_educ['Country Name'].str.contains("Russia", case=False)]
# Out:
#               Country Name Country Code  \
# 679229  Russian Federation          RUS
#
#                                            Indicator Name       2014
# 679229  Enrolment in tertiary education, all programme...  6995732.0

# %%
# Colombia
ter_educ.loc[ter_educ['Country Name'].str.contains("Colombia", case=False)]
# Out:
#        Country Name Country Code  \
# 246759     Colombia          COL
#
#                                            Indicator Name       2014
# 246759  Enrolment in tertiary education, all programme...  2220652.0

# %%
# ter educ dataframe 
tertiary_enrollment = ter_educ.loc[[664569,246759,679229,836824,558284,844154,188119,818499,675564,565614,583939,386029,210109,510639,745199,356709]]
tertiary_enrollment = pd.DataFrame(tertiary_enrollment) 
tertiary_enrollment
# Out:
#               Country Name Country Code  \
# 664569            Portugal          PRT
# 246759            Colombia          COL
# 679229  Russian Federation          RUS
# 836824             Ukraine          UKR
# 558284              Mexico          MEX
# 844154      United Kingdom          GBR
# 188119              Brazil          BRA
# 818499              Turkey          TUR
# 675564             Romania          ROU
# 565614             Moldova          MDA
# 583939          Mozambique          MOZ
# 386029              Guinea          GIN
# 210109          Cabo Verde          CPV
# 510639           Lithuania          LTU
# 745199               Spain          ESP
# 356709             Germany          DEU
#
#                                            Indicator Name        2014
# 664569  Enrolment in tertiary education, all programme...   362200.00
# 246759  Enrolment in tertiary education, all programme...  2220652.00
# ...

# %% [markdown]
# Merging Datasets

# %%
# merging secondary and teritary enrollment 
enrollment = tertiary_enrollment.merge(secondary_enrollment, how='outer')
enrollment
# Out:
#           Country Name Country Code  \
# 0             Portugal          PRT
# 1             Colombia          COL
# 2   Russian Federation          RUS
# 3              Ukraine          UKR
# 4               Mexico          MEX
# 5       United Kingdom          GBR
# 6               Brazil          BRA
# 7               Turkey          TUR
# 8              Romania          ROU
# 9              Moldova          MDA
# 10          Mozambique          MOZ
# 11              Guinea          GIN
# 12          Cabo Verde          CPV
# 13           Lithuania          LTU
# 14               Spain          ESP
# 15             Germany          DEU
# 16               Spain          ESP
# 17            Portugal          PRT
# 18      United Kingdom          GBR
# 19           Lithuania          LTU
# 20          Cabo Verde          CPV
# 21              Guinea          GIN
# 22          Mozambique          MOZ
# 23             Romania          ROU
# 24             Moldova          MDA
# ...

# %%
# merging enrollment and gradrates 
ed_data = pd.concat([grad_rates,enrollment])
ed_data
# Out:
#     Marital status  Application mode  Application order  Course  \
# 0              1.0              17.0                5.0   171.0
# 1              1.0              15.0                1.0  9254.0
# 2              1.0               1.0                5.0  9070.0
# 3              1.0              17.0                2.0  9773.0
# 4              2.0              39.0                1.0  8014.0
# ..             ...               ...                ...     ...
# 22             NaN               NaN                NaN     NaN
# 23             NaN               NaN                NaN     NaN
# 24             NaN               NaN                NaN     NaN
# 25             NaN               NaN                NaN     NaN
# 26             NaN               NaN                NaN     NaN
#
#     Daytime/evening attendance\t  Previous qualification  \
# 0                            1.0                     1.0
# 1                            1.0                     1.0
# ...

# %% [markdown]
# Save Data

# %%
# save the data to a new csv file
datapath = '../data'
save_file(ed_data, 'ed_data_cleaned.csv', datapath)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [86], in <cell line: 3>()
#       1 # save the data to a new csv file
#       2 datapath = '../data'
# ----> 3 save_file(ed_data, 'ed_data_cleaned.csv', datapath)
#
# NameError: name 'save_file' is not defined
